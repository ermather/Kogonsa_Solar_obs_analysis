# %%
import numpy as np
import pandas as pd
import geopandas as gpd

# %%
gpd.read_file('./AV_ResearchForward_Sites/AV_ResearchForward_Sites.shp')
# Out:
#    Shape_Leng  Shape_Area                                           geometry
# 0   79.924095  343.724062  POLYGON Z ((577689.282 276482.588 0, 577716.70...
# 1  124.644262  572.037534  POLYGON Z ((577738.505 276318.786 0, 577738.74...
# 2  116.013213  339.047748  POLYGON Z ((577789.094 276291.619 0, 577789.80...
